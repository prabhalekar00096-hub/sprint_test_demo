# %%
# !pip install numpy pandas

# %%
import pandas as pd

# %%
import numpy as np

# %%
import sys 
sys.executable
# Out:
# '/home/praveen/anaconda3/bin/python'

# %%
# !conda install -y numpy pandas
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - defaults
#  - conda-forge
#  - pytorch
# Platform: linux-64
# ...
# Solving environment: \

# %%
import pandas as pd
import numpy as np
print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.2.6

# %%
# !pip install numpy pandas --quiet

# %%
import os
os.listdir()
# Out:
# ['Coll.ipynb', 'laptop_price.csv', '.ipynb_checkpoints']

# %%
df=pd.read_csv("laptop_price.csv",encoding='latin')
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.drop(columns=['laptop_ID'],inplace=True)

# %%
df.drop(columns=['Product'],inplace=True)

# %%
df=df[df.groupby('Company')['Company'].transform('count')>20].reset_index(drop=True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1247  Lenovo  2 in 1 Convertible    14.0
# 1248  Lenovo  2 in 1 Convertible    13.3
# 1249  Lenovo            Notebook    14.0
# 1250      HP            Notebook    15.6
# 1251    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1247   IPS Panel Full HD / Touchscreen 1920x1080
# 1248  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1218    Asus            Notebook    15.6
# 1219  Lenovo  2 in 1 Convertible    14.0
# 1220  Lenovo  2 in 1 Convertible    13.3
# 1221  Lenovo            Notebook    14.0
# 1222      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1218                                    1366x768
# 1219   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
# ===================================
# Section for CPU column Cleaning
#Colloborator: USER1
# ===================================

# %%
# ===================================
# Section for RAM and weight columns Cleaning
#Colloborator: USER2
# ===================================
